# %% [markdown]
# # MLE with Normal Distributions - Lab
#
# ## Introduction
#
# In this lab, we shall put in practice, the mathematical formulas we saw in previous lesson to see how MLE works with normal distributions.
#
# ## Objectives
# You will be able to:
#
# * Understand and describe how MLE works with normal distributions
# * Fit a normal distribution to given data identifying mean and variance
# * Visually compare the fitted distribution vs. real distribution

# %% [markdown]
# **Note:** *A detailed derivation of all MLE equations with proofs can be seen [at this website](https://www.statlect.com/fundamentals-of-statistics/normal-distribution-maximum-likelihood). *
#
# ## MLE in Python
#
# Let's see an example of MLE and distribution fittings with Python below. Here `scipy.stats.norm.fit` calculates the distribution parameters using Maximum Likelihood Estimation.

# %% [markdown]
# ### Import necessary libraries

# %%
from scipy.stats import norm # for generating sample data and fitting distributions
import scipy.stats as stats
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import numpy as np

# %% [markdown]
# ### Generate an array of 200 random sample from a normal dist with mean 0 and stdv 1

# %%
np.random.seed(200)
sample = np.random.normal(0, 1, 200)
sample
# Out:
# array([-1.45094825,  1.91095313,  0.71187915, -0.24773829,  0.36146623,
#        -0.03294967, -0.22134672,  0.47725678, -0.69193937,  0.79200593,
#         0.07324913,  1.30328603,  0.21348149,  1.01734895,  1.91171178,
#        -0.52967163,  1.84213516, -1.05723508, -0.86291629,  0.2376315 ,
#        -1.15418177,  1.21498404, -1.29375908,  0.82272281, -0.33215113,
#        -1.28142901,  0.21853781,  2.08347422, -0.24821806,  0.2674604 ,
#         0.7125135 , -0.65360768,  0.16227964,  2.2133805 , -0.66553423,
#        -1.00900322,  2.34805122,  0.60437586,  0.6438291 , -0.33175226,
#         0.06986397, -0.01471103,  1.71106875, -0.35644507,  0.64311606,
#        -0.24088278, -2.55798096, -1.95566295,  0.02570574,  0.77328417,
#         2.18609495,  1.77857249,  0.3401741 , -0.21351859,  1.11773591,
#         0.94702945,  0.2630036 , -1.86793528, -0.3916012 , -1.15141763,
#         0.09743798,  1.58203196, -0.48286855,  0.19991277, -0.29465727,
#         0.97823615, -0.03008042, -0.68652344,  0.04974017,  1.33764141,
#        -0.2327679 ,  0.55370177, -1.52007408,  1.19279792,  0.52518578,
#        -0.84640754, -0.1968985 , -0.86301704,  0.98530909, -0.03143433,
#        -0.98463583,  2.24698967, -0.05358755,  0.55642577, -2.00653453,
#        -0.68322017,  0.46313872, -0.56406935, -0.40408192, -1.638067  ,
#        -0.15125239,  0.90744408,  0.0673945 ,  0.69049189, -0.06996847,
#         0.74731893, -0.30642407,  0.18199109, -0.07213603,  2.21796653,
#         0.2584544 , -0.73603076,  0.31125086, -0.11879521,  0.77047831,
#        -1.14883292, -0.27289366, -0.12485667,  0.62675835,  1.15805552,
#         0.35786937,  0.52423795, -0.88974969,  0.73690722,  1.61904563,
#         0.21215972,  0.03181006,  1.20272375,  0.29745439, -0.75361164,
#        -0.21495011, -0.41238072, -1.07824164,  1.2124852 , -0.35463776,
#        -0.46698477, -0.66643198, -0.24249065, -1.0844555 , -0.07992433,
#         0.805794  , -0.04241359, -0.69537307, -0.13390765, -1.95027664,
#        -0.63517242,  0.76579565, -0.63968302, -0.60884936, -0.13055295,
#         0.25737463, -1.86451829,  0.49022774, -1.01929046, -0.41132865,
#         0.21408824, -0.43895725, -0.6792212 ,  2.39702707,  1.31594368,
#        -0.35957085, -0.13549052,  0.382583  ,  0.42273453,  1.38609443,
#         1.00001438,  0.81490518, -0.43224009,  1.26157625,  1.03588743,
#         0.0888159 , -0.96813926,  0.53459462,  0.66597247,  0.49985347,
#         0.32154286,  0.59944615, -0.29594898,  1.22923449,  0.01007315,
#         0.72311791, -1.42595201,  0.03292246, -0.8677184 ,  0.69673284,
#        -0.11856477, -1.74434015, -1.56145563, -0.64653444,  0.0204526 ,
#         0.44375837,  1.46492525, -1.11952533,  0.52045974,  0.75272929,
#        -0.14479561,  0.06542526, -0.84437193, -0.94861729, -0.95172629,
#        -0.19478459, -1.25115029,  0.2455297 , -1.06997395, -0.25665373,
#        -0.04667467,  1.92273803, -1.76498398,  0.59205971,  1.90577562])

# %% [markdown]
# ### Distribution fitting through MLE
# #### -  Use `stats.norm.fit(data)` to fit a distribution to above data.
# #### - This returns a list of two parameters : (mean,: parameters[0] and std:  parameters[1]) via a MLE approach

# %%
param = stats.norm.fit(sample)
param[0], param[1]
# (0.08241224761452863, 1.002987490235812)
# Out:
# (0.07404723790558142, 0.9612657088004906)

# %% [markdown]
# ### Calculate the PDF from a) actual data parameters b) fitted parameters with `x = np.linspace(-5,5,100)`

# %%
x = np.linspace(-5,5,200)

# Generate the pdf from fitted parameters (fitted distribution)
fitted_pdf = norm.pdf(x,loc = param[0],scale = param[1])
# Generate the pdf without fitting (normal distribution non fitted)
normal_pdf = norm.pdf(x)

# %% [markdown]
# ### Visualize both PDFs

# %%
# plt.figure(figsize=(10,7))
# plt.plot(x, fitted_pdf, '-')
# plt.plot(x, normal_pdf)
# plt.title("Normal distribution MLE fitting", fontsize=16);

from pylab import rcParams
rcParams['figure.figsize'] = 15, 8
plt.plot(x,fitted_pdf,"red",label="Fitted MLE dist",linestyle="dashed", linewidth=2)
plt.plot(x,normal_pdf,"blue",label="Normal dist", linewidth=2)
plt.hist(sample,normed=1,color="cyan",alpha=.3, label='Random Sample')
plt.title("Normal distribution MLE fitting")
plt.legend()

plt.show()
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
#  Your comments/observations

# %% [markdown]
# ## Summary

# %% [markdown]
# In this short lab, we looked at Bayesian setting in a Gaussian context i.e. when the underlying random variables are normally distributed. We learned that MLE can estimate the unknown parameters of a normal distribution, by maximizing the likelihood of expected mean. The expected mean comes very close to the mean of a non-fitted normal distribution within that parameter space. We shall move ahead with this understanding towards learning how such estimations are performed in estimating means of a number of classes present in the data distribution using Naive Bayes Classifier.
